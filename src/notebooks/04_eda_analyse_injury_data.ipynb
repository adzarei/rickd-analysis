# %% [markdown]
# # Injury Analysis:
#
# - Identify the unique injuries present in the dataset for self assessment and the diagnostic of the professional medical reviewer.
# - Provide a description of the injuries.
# - Analyse the relationship between self-assessment and the diagnostic of the medical reviewer.
# - Decide if self assessment adds information.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
from core.constants import RICKD_RESULTS_FOLDER, RICKD_SESSION_DATA_FULL_FILE

run_data_full = pd.read_csv(RICKD_SESSION_DATA_FULL_FILE)
run_injury_data = run_data_full[['id', 'sub_id','InjDefn', 'SpecInjury', 'SpecInjury2', 'InjJoint', 'InjJoint2', 'InjSide', 'InjSide2']]
run_injury_data
# Out:
#                           id  sub_id                             InjDefn  \
# 0     100433_20101005t132240  100433  training volume/intensity affected
# 1     100434_20101117t132240  100434  training volume/intensity affected
# 2     100537_20120703t102550  100537          2 workouts missed in a row
# 3     100560_20120717t103748  100560                           no injury
# 4     101481_20120717t105021  101481                           no injury
# ...                      ...     ...                                 ...
# 1827  200986_20150312t143944  200986                           no injury
# 1828  200987_20150312t160840  200987         continuing to train in pain
# 1829  201100_20150409t155915  201100  training volume/intensity affected
# 1830  201101_20150413t143152  201101                           no injury
# 1831  201099_20150414t092041  201099         continuing to train in pain
#
#                SpecInjury      SpecInjury2             InjJoint  InjJoint2  \
# 0                    pain              NaN                 knee  no injury
# 1       disc degeneration              NaN         lumbar spine  no injury
# 2                   other              NaN           hip/pelvis  no injury
# 3                     NaN              NaN            no injury  no injury
# 4                     NaN              NaN  no injury,no injury        NaN
# ...                   ...              ...                  ...        ...
# 1827                  NaN              NaN                  NaN        NaN
# 1828  pelvic malalignment     itb syndrome           hip/pelvis      thigh
# 1829        muscle strain  ligament sprain         lumbar spine      ankle
# 1830                  NaN              NaN                  NaN        NaN
# 1831                other              NaN                 foot        NaN
#
#         InjSide InjSide2
# 0         right    right
# 1     bilateral    right
# 2         right    right
# 3         right    right
# 4           NaN      NaN
# ...         ...      ...
# 1827        NaN      NaN
# 1828      right     left
# 1829  bilateral    right
# 1830        NaN      NaN
# 1831      right      NaN
#
# [1832 rows x 9 columns]

# %%
print(f"Num of NaN in SpecInjury: {run_injury_data[run_injury_data.SpecInjury.isna()].sub_id.count()}")
print(f"Num of no injury in SpecInjury: {run_injury_data[run_injury_data.SpecInjury == 'no injury'].sub_id.count()}")
# Out:
# Num of NaN in SpecInjury: 588
# Num of no injury in SpecInjury: 70

# %%
display(run_injury_data['InjJoint'].value_counts(dropna=False).sort_index(ascending=True))
display(run_injury_data['InjJoint2'].value_counts(dropna=False).sort_index(ascending=True))
display(run_injury_data['InjSide'].value_counts(dropna=False).sort_index(ascending=True))
display(run_injury_data['InjSide2'].value_counts(dropna=False).sort_index(ascending=True))
# Out:
# InjJoint
# ankle                  107
# foot                   141
# hip/pelvis             136
# knee                   348
# lower leg              185
# lumbar spine            41
# no injury              228
# no injury,no injury    189
# other                   20
# sacroiliac joint        22
# thigh                  181
# NaN                    234
# Name: count, dtype: int64
# InjJoint2
# ankle                40
# foot                 51
# hip/pelvis           59
# knee                 67
# lower leg            38
# lumbar spine         23
# no injury           514
# other                 3
# sacroiliac joint     10
# thigh                31
# NaN                 996
# Name: count, dtype: int64
# InjSide
# bi-lateral      3
# bilateral     305
# left          406
# right         632
# NaN           486
# Name: count, dtype: int64
# InjSide2
# bilateral     100
# left          100
# right         622
# NaN          1010
# Name: count, dtype: int64

# %% [markdown]
# ## Clean Injury type:
# Clean injury type introducing codes that are easier to handle. Remove duplciates and add descriptions.

# %%
# Combine SpecInjury and SpecInjury2 columns and get unique values
unique_combined_injuries = pd.concat([run_injury_data['SpecInjury'], run_injury_data['SpecInjury2']]).dropna().drop_duplicates()

print("### Distinct Injury Types")
for injury in sorted(unique_combined_injuries):
    print(f"- {injury}")
# Out:
# ### Distinct Injury Types
# - achilles tendonitis
# - bursitis
# - calf muscle strain
# - chondromalacia
# - compartment syndrome
# - cyst
# - deformity (e.g hammer/claw toes, bunion)
# - deformity(ie hammer/claw toes, bunion)
# - disc degeneration
# - disc protrusion
# - dislocation
# - fibula fracture
# - fibula stress fracture
# - fill in specifics below
# - first ray tendonitis (turf toe)
# - gastrocnemius strain
# - groin muscle strain
# - hamstring muscle strain
# - high ankle sprain with tendonosis
# - hip flexor strain
# - hip joint irritation
# - ischial bursitis
# - itb syndrome
# - labral tear
# - ligament sprain
# - ligament tear/rupture acl
# - ligament tear/rupture mcl
# - ligament tear/rupture pcl
# - ligament tear/rupture-acl
# - low back pain
# - medial tibial stress syndrome
# - meniscal tear medial
# - meniscal tear-lateral
# - meniscal tear-medial
# - metarsalgia
# - metatarsal stress fracture
# - muscle spasm
# - muscle strain
# - mva, not running related
# - nerve impingement
# - no injury
# - non-specific injury
# - osteitis pubis
# - osteoarthritis
# - other
# - pain
# - patellar fracture
# - patellar tedonitis
# - patellar tendonitis
# - patellofemoral pain syndrome
# - pelvic dysfunction general
# - pelvic malalignment
# - peroneal tendonitis
# - pes anserine bursitis
# - pfps
# - piriformis syndrome
# - plantar fasciitis
# - plica
# - sciatic nerve impingement
# - shin splints
# - si joint pain
# - strain
# - stress fracture
# - stress reaction
# - synovitis
# - tendonitis
# - tibia fracture
# - tibia stress fracture

# %%
from core.data_quality import map_injury_codes
from core.constants import RICKD_MAP_INJURY_CODE, RICKD_MAP_INJURY_DESC, RICKD_MAP_SELF_INJURY_CODE, RICKD_MAP_INJURED_JOINT, RICKD_MAP_INJURED_JOINT_SIDE
from core.utils import save_df_as_table_image


df = run_injury_data.copy()
df = map_injury_codes(df, RICKD_MAP_SELF_INJURY_CODE, "InjDefn", "injury_severity_code", map_key_col="key", map_value_col="value")
df = map_injury_codes(df, RICKD_MAP_SELF_INJURY_CODE, "InjDefn", "injury_severity_value", map_key_col="key", map_value_col="num_value")
df = map_injury_codes(df, RICKD_MAP_INJURED_JOINT, "InjJoint", "injured_joint_code", map_key_col="orig_value", map_value_col="code")
df = map_injury_codes(df, RICKD_MAP_INJURED_JOINT, "InjJoint2", "injured_joint2_code", map_key_col="orig_value", map_value_col="code")
df = map_injury_codes(df, RICKD_MAP_INJURED_JOINT_SIDE, "InjSide", "injured_side_code", map_key_col="orig_value", map_value_col="code")
df = map_injury_codes(df, RICKD_MAP_INJURED_JOINT_SIDE, "InjSide2", "injured_side2_code", map_key_col="orig_value", map_value_col="code")
df = map_injury_codes(df, RICKD_MAP_INJURY_CODE, "SpecInjury", "injury_code", map_key_col="orig_value", map_value_col="code")
df = map_injury_codes(df, RICKD_MAP_INJURY_CODE, "SpecInjury2", "injury2_code", map_key_col="orig_value", map_value_col="code")
df = map_injury_codes(df, RICKD_MAP_INJURY_DESC, "injury_code", "injury_desc", map_key_col="code", map_value_col="desc")
df = map_injury_codes(df, RICKD_MAP_INJURY_DESC, "injury_code", "injury_name", map_key_col="code", map_value_col="name")
df = map_injury_codes(df, RICKD_MAP_INJURY_DESC, "injury2_code", "injury2_desc", map_key_col="code", map_value_col="desc")
df = map_injury_codes(df, RICKD_MAP_INJURY_DESC, "injury2_code", "injury2_name", map_key_col="code", map_value_col="name")

clean_injury_data = df.copy()
clean_injury_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1832 entries, 0 to 1831
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1832 non-null   object
#  1   sub_id                 1832 non-null   int64
#  2   InjDefn                1752 non-null   object
#  3   SpecInjury             1244 non-null   object
#  4   SpecInjury2            269 non-null    object
#  5   InjJoint               1598 non-null   object
#  6   InjJoint2              836 non-null    object
#  7   InjSide                1346 non-null   object
#  8   InjSide2               822 non-null    object
#  9   injury_severity_code   1752 non-null   object
#  10  injury_severity_value  1752 non-null   float64
#  11  injured_joint_code     1832 non-null   object
#  12  injured_joint2_code    1832 non-null   object
#  13  injured_side_code      1832 non-null   object
#  14  injured_side2_code     1832 non-null   object
#  15  injury_code            1832 non-null   object
#  16  injury2_code           1832 non-null   object
#  17  injury_desc            1832 non-null   object
#  18  injury_name            1832 non-null   object
#  19  injury2_desc           1832 non-null   object
#  20  injury2_name           1832 non-null   object
# dtypes: float64(1), int64(1), object(19)
# memory usage: 300.7+ KB

# %%
# There are two situations where the injury2_code reports an injury but the injury_code is no_injury.
# Here we should flip injury2_code and injury_code, also injured_joint2_code, injured_joint_code, injured_side2_code, injured_side_code, injury2_desc, injury_desc, injury2_name, injury_name

# Find rows where injury_code is "no_injury" and injury2_code is not "no_injury"
mask = (clean_injury_data.injury_code == "no_injury") & (clean_injury_data.injury2_code != "no_injury")

# Columns to flip
cols_to_flip = [
    "injury_code", "injury2_code",
    "injured_joint_code", "injured_joint2_code",
    "injured_side_code", "injured_side2_code",
    "injury_desc", "injury2_desc",
    "injury_name", "injury2_name"
]
print("Before")
display(clean_injury_data[["id", *cols_to_flip]][mask])
original_ids = clean_injury_data.index[mask]

# Actually swap the values between the columns for the selected rows
for col1, col2 in zip(cols_to_flip[::2], cols_to_flip[1::2]):
    temp = clean_injury_data.loc[mask, col1].copy()
    clean_injury_data.loc[mask, col1] = clean_injury_data.loc[mask, col2]
    clean_injury_data.loc[mask, col2] = temp

print("After")
display(clean_injury_data[["id", *cols_to_flip]].loc[original_ids])
# Out:
# Before
#                          id injury_code injury2_code injured_joint_code  \
# 9    100671_20121213t105755   no_injury         pain              other
# 924  100713_20130404t101951   no_injury         burs              other
#
#     injured_joint2_code injured_side_code injured_side2_code  \
# 9          lumbar_spine             right               left
# 924          hip_pelvis             right              right
#
#                        injury_desc  \
# 9    No injury has been diagnosed.
# 924  No injury has been diagnosed.
#
#                                           injury2_desc injury_name  \
# 9    General sensation of discomfort  without speci...   no injury
# 924  Inflammation of joint cushioning sacs due to r...   no injury
#
#     injury2_name
# 9           pain
# 924     bursitis
# After
#                          id injury_code injury2_code injured_joint_code  \
# 9    100671_20121213t105755        pain    no_injury       lumbar_spine
# 924  100713_20130404t101951        burs    no_injury         hip_pelvis
#
#     injured_joint2_code injured_side_code injured_side2_code  \
# 9                 other              left              right
# 924               other             right              right
#
#                                            injury_desc  \
# 9    General sensation of discomfort  without speci...
# 924  Inflammation of joint cushioning sacs due to r...
#
#                       injury2_desc injury_name injury2_name
# 9    No injury has been diagnosed.        pain    no injury
# 924  No injury has been diagnosed.    bursitis    no injury

# %%
# Create a new dataframe with all columns from run_data_full plus the new mapped columns from df
run_data_full_with_injury_codes = pd.concat([
    run_data_full,
    clean_injury_data[
        ['injury_severity_code', 'injury_severity_value', 'injury_code',
         'injury2_code', 'injury_desc', 'injury2_desc', 'injury_name', 'injury2_name',
         'injured_joint_code', 'injured_joint2_code', 'injured_side_code', 'injured_side2_code'
         ]
    ]
], axis=1)

run_data_full_with_injury_codes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1832 entries, 0 to 1831
# Columns: 193 entries, id to injured_side2_code
# dtypes: float64(87), int64(79), object(27)
# memory usage: 2.7+ MB

# %% [markdown]
# ## Analyse Injury data:
# - Describe types of injuries.
# - Relationship between self-assessment and the diagnostic of the medical reviewer.

# %%
# Get unique values and their counts from InjDefn column
injury_defn_counts = clean_injury_data['InjDefn'].value_counts(dropna=False)
injury_defn_counts
# Out:
# InjDefn
# no injury                             659
# training volume/intensity affected    499
# continuing to train in pain           320
# 2 workouts missed in a row            274
# NaN                                    80
# Name: count, dtype: int64

# %%
clean_injury_data['injury2_code'].value_counts(dropna=False).sort_index(ascending=True)
# Out:
# injury2_code
# achi_tend                13
# burs                      9
# calf_musc_stra            7
# comp_synd                 1
# disc_dege                 4
# disc_prot                 2
# groin_musc_stra           3
# hams_musc_stra           15
# hip_flex_stra             1
# hip_joint_irri            1
# itb_synd                 14
# liga_spra                 5
# liga_tear_acl             2
# liga_tear_mcl             3
# low_back_pain             7
# medi_tibi_stre_synd       3
# meni_tear_med             9
# musc_spasm                3
# no_injury              1566
# oste_pubis                1
# osteoar                   3
# pain                     95
# pate_pain_synd           14
# pate_tend                 4
# pelv_dysf_gene            1
# pero_tend                 6
# plan_fasc                22
# scia_nerve_impi           1
# shin_spli                 7
# si_joint_pain             3
# strain                    3
# tend                      1
# tibia_stre_frac           3
# Name: count, dtype: int64

# %%
# Combine SpecInjury/injury_code and SpecInjury2/injury2_code into a single dataframe
medical_reviewer_injury = pd.concat([
    clean_injury_data[['injury_code']].rename(columns={'injury_code': 'Code'}),
    clean_injury_data[clean_injury_data['injury2_code'] != 'healthy'][['injury2_code']].rename(columns={'injury2_code': 'Code'})
])

medical_reviewer_injury_counts = medical_reviewer_injury.value_counts().sort_values(ascending=False)

with pd.option_context('display.max_rows', None):
    display(medical_reviewer_injury_counts)
# Out:
# Code
# no_injury                    2231
# pain                          513
# pate_pain_synd                148
# itb_synd                      140
# achi_tend                      75
# plan_fasc                      72
# calf_musc_stra                 63
# hams_musc_stra                 46
# shin_spli                      43
# burs                           33
# medi_tibi_stre_synd            33
# pero_tend                      18
# pate_tend                      18
# tibia_stre_frac                18
# osteoar                        17
# low_back_pain                  16
# tend                           16
# meni_tear_med                  14
# si_joint_pain                  10
# liga_tear_acl                  10
# oste_pubis                      9
# liga_spra                       9
# hip_flex_stra                   8
# disc_dege                       8
# disc_prot                       8
# musc_spasm                      8
# chon                            7
# pelv_dysf_gene                  7
# comp_synd                       5
# groin_musc_stra                 5
# deformity                       4
# strain                          4
# piri_synd                       4
# liga_tear_mcl                   3
# first_ray_tend                  3
# meta_stre_frac                  3
# meta                            3
# cyst                            3
# pes_anse_burs                   2
# hip_joint_irri                  2
# stre_frac                       2
# musc_stra                       2
# nerve_impi                      2
# pelv_mala                       2
# plica                           2
# scia_nerve_impi                 1
# pate_frac                       1
# gast_stra                       1
# disl                            1
# labr_tear                       1
# meni_tear_lat                   1
# liga_tear_pcl                   1
# tibia_frac                      1
# fibu_stre_frac                  1
# motor_vehi_acci                 1
# stre_reac                       1
# syno                            1
# high_ankle_spra_with_tend       1
# isch_burs                       1
# fibu_frac                       1
# Name: count, dtype: int64

# %%
df = pd.read_csv(RICKD_MAP_INJURY_CODE).sort_values(by='code')
save_df_as_table_image(
    df,
    os.path.join(RICKD_RESULTS_FOLDER, 'injury_code_mapping.png')
)
display(df)
# Out:
#                orig_value             code
# 0     achilles tendonitis        achi_tend
# 1                bursitis             burs
# 2      calf muscle strain   calf_musc_stra
# 3          chondromalacia             chon
# 4    compartment syndrome        comp_synd
# ..                    ...              ...
# 65        stress reaction        stre_reac
# 66              synovitis             syno
# 67             tendonitis             tend
# 68         tibia fracture       tibia_frac
# 69  tibia stress fracture  tibia_stre_frac
#
# [70 rows x 2 columns]

# %%
df = medical_reviewer_injury_counts.reset_index()
save_df_as_table_image(
    df,
    os.path.join(RICKD_RESULTS_FOLDER, 'medical_reviewer_injury_counts_sorted.png')
)
display(df)
# Out:
#                          Code  count
# 0                   no_injury   2231
# 1                        pain    513
# 2              pate_pain_synd    148
# 3                    itb_synd    140
# 4                   achi_tend     75
# 5                   plan_fasc     72
# 6              calf_musc_stra     63
# 7              hams_musc_stra     46
# 8                   shin_spli     43
# 9                        burs     33
# 10        medi_tibi_stre_synd     33
# 11                  pero_tend     18
# 12                  pate_tend     18
# 13            tibia_stre_frac     18
# 14                    osteoar     17
# 15              low_back_pain     16
# 16                       tend     16
# 17              meni_tear_med     14
# 18              si_joint_pain     10
# 19              liga_tear_acl     10
# 20                 oste_pubis      9
# 21                  liga_spra      9
# 22              hip_flex_stra      8
# 23                  disc_dege      8
# 24                  disc_prot      8
# 25                 musc_spasm      8
# 26                       chon      7
# 27             pelv_dysf_gene      7
# 28                  comp_synd      5
# 29            groin_musc_stra      5
# 30                  deformity      4
# 31                     strain      4
# 32                  piri_synd      4
# 33              liga_tear_mcl      3
# 34             first_ray_tend      3
# 35             meta_stre_frac      3
# 36                       meta      3
# 37                       cyst      3
# 38              pes_anse_burs      2
# 39             hip_joint_irri      2
# 40                  stre_frac      2
# 41                  musc_stra      2
# 42                 nerve_impi      2
# 43                  pelv_mala      2
# 44                      plica      2
# 45            scia_nerve_impi      1
# 46                  pate_frac      1
# 47                  gast_stra      1
# 48                       disl      1
# 49                  labr_tear      1
# 50              meni_tear_lat      1
# 51              liga_tear_pcl      1
# 52                 tibia_frac      1
# 53             fibu_stre_frac      1
# 54            motor_vehi_acci      1
# 55                  stre_reac      1
# 56                       syno      1
# 57  high_ankle_spra_with_tend      1
# 58                  isch_burs      1
# 59                  fibu_frac      1

# %%
N=20
df = medical_reviewer_injury_counts.reset_index().sort_values(by='count', ascending=False).head(20)
save_df_as_table_image(
    df,
    os.path.join(RICKD_RESULTS_FOLDER, f'medical_reviewer_injury_counts_top{N}.png')
)
display(df)
# Out:
#                    Code  count
# 0             no_injury   2231
# 1                  pain    513
# 2        pate_pain_synd    148
# 3              itb_synd    140
# 4             achi_tend     75
# 5             plan_fasc     72
# 6        calf_musc_stra     63
# 7        hams_musc_stra     46
# 8             shin_spli     43
# 9                  burs     33
# 10  medi_tibi_stre_synd     33
# 11            pero_tend     18
# 12            pate_tend     18
# 13      tibia_stre_frac     18
# 14              osteoar     17
# 16                 tend     16
# 15        low_back_pain     16
# 17        meni_tear_med     14
# 18        si_joint_pain     10
# 19        liga_tear_acl     10

# %%
subject_pace = run_data_full_with_injury_codes.groupby('sub_id')['speed_r'].mean().reset_index()

# Get most common injury per subject
subject_injuries = pd.concat([
    run_data_full_with_injury_codes[['sub_id', 'injury_code']].rename(columns={'injury_code': 'Code'}),
    run_data_full_with_injury_codes[run_data_full_with_injury_codes['injury2_code'] != 'healthy'][['sub_id', 'injury2_code']].rename(columns={'injury2_code': 'Code'})
])

most_common_injury = subject_injuries.groupby('sub_id')['Code'].agg(
    lambda x: x.value_counts().index[0] if len(x) > 0 else 'healthy'
).reset_index()

subject_summary = pd.merge(subject_pace, most_common_injury, on='sub_id').rename(columns={'speed_r': 'pace (m/s)', 'Code': 'Injury Code'})

injury_pace_summary = subject_summary.groupby('Injury Code')['pace (m/s)'].agg(['mean', 'count']).reset_index()
injury_pace_summary = injury_pace_summary.sort_values('mean', ascending=False).rename(columns={'mean': 'mean pace (m/s)'})

display(injury_pace_summary)

save_df_as_table_image(
    injury_pace_summary,
    os.path.join(RICKD_RESULTS_FOLDER, 'injury_pace_summary.png')
)
# Out:
#             Injury Code  mean pace (m/s)  count
# 49            stre_frac         3.290489      1
# 33           oste_pubis         3.044357      4
# 40            pelv_mala         3.001225      2
# 54      tibia_stre_frac         2.966210      7
# 25        meni_tear_lat         2.925006      1
# 50            stre_reac         2.914865      1
# 39       pelv_dysf_gene         2.840566      3
# 38            pate_tend         2.836377      9
# 13      groin_musc_stra         2.779100      2
# 48               strain         2.750950      1
# 12       first_ray_tend         2.743887      2
# 52                 tend         2.742101     10
# 43            piri_synd         2.740363      4
# 32            no_injury         2.730116    450
# 21        liga_tear_acl         2.725213      7
# 46            shin_spli         2.715657     18
# 9                  disl         2.714334      1
# 0             achi_tend         2.685017     46
# 2        calf_musc_stra         2.674964     42
# 14       hams_musc_stra         2.663484     28
# 4             comp_synd         2.660919      4
# 41            pero_tend         2.637599      7
# 18             itb_synd         2.635398     97
# 8             disc_prot         2.629910      6
# 15        hip_flex_stra         2.621655      7
# 3                  chon         2.605767      5
# 37       pate_pain_synd         2.604184    128
# 42        pes_anse_burs         2.604173      2
# 1                  burs         2.589310     19
# 28       meta_stre_frac         2.580745      3
# 24  medi_tibi_stre_synd         2.557675     30
# 30            musc_stra         2.556826      2
# 29           musc_spasm         2.556336      5
# 19            labr_tear         2.553746      1
# 35                 pain         2.547406    345
# 27                 meta         2.516760      3
# 47        si_joint_pain         2.507067      5
# 23        low_back_pain         2.487887      8
# 36            pate_frac         2.487418      1
# 31           nerve_impi         2.478995      2
# 11       fibu_stre_frac         2.467502      1
# 44            plan_fasc         2.422556     43
# 45                plica         2.381548      2
# 22        liga_tear_pcl         2.368374      1
# 20            liga_spra         2.360381      4
# 7             disc_dege         2.277493      4
# 26        meni_tear_med         2.259916      5
# 17            isch_burs         2.252645      1
# 34              osteoar         2.251815     12
# 53           tibia_frac         2.234999      1
# 5                  cyst         2.154007      3
# 51                 syno         2.153993      1
# 6             deformity         2.034100      4
# 16       hip_joint_irri         2.016002      1
# 10            fibu_frac         1.655980      1

# %%
run_data_full_with_injury_codes['datestring'] = pd.to_datetime(run_data_full_with_injury_codes['datestring'])

# Get all dates for each subject
subject_dates = run_data_full_with_injury_codes.groupby('sub_id')['datestring'].apply(list).reset_index()

def is_longitudinal(dates):
    if len(dates) < 2:
        return False
    dates = sorted(dates)
    for i in range(len(dates)-1):
        if (dates[i+1] - dates[i]).days < 30:
            return False
    return True

# Apply the check to each subject
subject_dates['is_longitudinal'] = subject_dates['datestring'].apply(is_longitudinal)
longitudinal_subjects = subject_dates[subject_dates['is_longitudinal']]

print(f"Number of subjects with longitudinal data (all sessions >= 1 month apart): {len(longitudinal_subjects)}")
print(f"Total number of subjects: {len(subject_dates)}")
print(f"Percentage of subjects with longitudinal data: {len(longitudinal_subjects)/len(subject_dates)*100:.1f}%")

# # Calculate and display time differences between consecutive sessions
# all_diffs = []
# for dates in subject_dates['datestring']:
#     dates = sorted(dates)
#     for i in range(len(dates)-1):
#         all_diffs.append((dates[i+1] - dates[i]).days / 30)

# print("\nSummary statistics of time differences between consecutive sessions (months):")
# print(pd.Series(all_diffs).describe())
# Out:
# Number of subjects with longitudinal data (all sessions >= 1 month apart): 30
# Total number of subjects: 1403
# Percentage of subjects with longitudinal data: 2.1%

# %%
for col in run_data_full_with_injury_codes.columns:
    print(col)
    # display(run_data_full_with_injury_codes[col].value_counts())
    try:
        print(f"Max value: {run_data_full_with_injury_codes[col].max()}")
        print(f"Min value: {run_data_full_with_injury_codes[col].min()}")
        if run_data_full_with_injury_codes[col].dtype != 'object':
            print(f"Mean value: {run_data_full_with_injury_codes[col].mean()}")
            print(f"Median value: {run_data_full_with_injury_codes[col].median()}")
    except:
        pass
# Out:
# id
# Max value: 300375_20140502t074159
# Min value: 100001_20110531t161051
# sub_id
# Max value: 300375
# Min value: 100001
# Mean value: 122830.82914847162
# Median value: 101256.0
# datestring
# Max value: 2017-06-29 12:56:14
# Min value: 2010-01-12 13:38:43
# Mean value: 2014-01-11 22:43:59.705817856
# Median value: 2014-06-18 01:13:49.500000
# filename
# Max value: 20170629t125614.json
# Min value: 20090527t000000.json
# speed_r
# Max value: 4.8769979791919
# Min value: 1.17204781550085
# Mean value: 2.760160124962194
# Median value: 2.72130971833423
# age
# Max value: 255
# Min value: 18
# Mean value: 38.169213973799124
# Median value: 37.0
# Height
# Max value: 999.0
# Min value: 0.0
# Mean value: 173.05191908146526
# Median value: 172.7
# Weight
# Max value: 1564.0
# Min value: 0.0
# Mean value: 71.01722255340289
# Median value: 69.1
# Gender
# Max value: unknown
# Min value: female
# DominantLeg
# InjDefn
# InjJoint
# InjSide
# SpecInjury
# InjDuration
# Max value: 30000.0
# Min value: 0.0
# Mean value: 450.4716049382716
# Median value: 120.0
# InjJoint2
# InjSide2
# SpecInjury2
# Activities
# Level
# YrsRunning
# Max value: 999.0
# Min value: 0.0
# Mean value: 49.122623574144484
# Median value: 8.0
# RaceDistance
# RaceTimeHrs
# Max value: 51.0
# Min value: 0.0
# Mean value: 2.1477477477477476
# Median value: 1.0
# RaceTimeMins
# Max value: 175.0
# Min value: 0.0
# Mean value: 32.312624821683315
# Median value: 34.0
# RaceTimeSecs
# Max value: 59.0
# Min value: 0.0
# Mean value: 10.130337078651685
# Median value: 0.0
# YrPR
# Max value: 2016.0
# Min value: 0.0
# Mean value: 1930.315294117647
# Median value: 2012.0
# NumRaces
# Max value: 30.0
# Min value: 0.0
# Mean value: 5.329365079365079
# Median value: 4.0
# sub_id_orig
# Max value: 201225
# Min value: 100001
# Mean value: 122721.65884279476
# Median value: 101256.0
# session_file_path
# Max value: 201225/20140515t133244.json
# Min value: 100001/20110531t161051.json
# l_step_width
# Max value: 0.177913669680285
# Min value: -0.0539706748809684
# Mean value: 0.05872372023110532
# Median value: 0.05867717712567255
# l_stride_rate
# Max value: 106.66877370417194
# Min value: 68.96551724137932
# Mean value: 83.32823636434989
# Median value: 83.04597701149424
# l_stride_length
# Max value: 3.4870535551222095
# Min value: Biomechanical injury sustained from motor vehicle accident unrelated to running.
# injury2_desc
# Max value: Tearing or rupture of medial knee ligament caused by lateral mechanical force.
# Min value: Breakdown and gradual loss of spinal disc cushioning due to repeated loading or aging.
# injury_name
# Max value: tibia stress fracture
# Min value: achilles tendonitis
# injury2_name
# Max value: tibia stress fracture
# Min value: achilles tendonitis
# injured_joint_code
# Max value: thigh
# Min value: ankle
# injured_joint2_code
# Max value: thigh
# Min value: ankle
# injured_side_code
# Max value: right
# Min value: bilateral
# injured_side2_code
# Max value: right
# Min value: bilateral

# %%
# Remove columns that have 0 in all values
zero_columns = []
for col in run_data_full_with_injury_codes.columns:
    if pd.api.types.is_numeric_dtype(run_data_full_with_injury_codes[col]):
        if (run_data_full_with_injury_codes[col] == 0).all():
            zero_columns.append(col)

cleaned_session_data_full_part1 = run_data_full_with_injury_codes.drop(columns=zero_columns)

# %%
print("Columns:")
for i, col in enumerate(zero_columns, 1):
    print(f"{i:3d}. {col}")
# Out:
# Columns:
#   1. l_pelvis_drop_percent_stance
#   2. l_pelvis_drop_at_hs
#   3. l_ankle_df_percent_stance
#   4. l_ankle_df_at_hs
#   5. l_ankle_df_excursion
#   6. l_ankle_eve_at_hs
#   7. l_ankle_rot_percent_stance
#   8. l_ankle_rot_at_hs
#   9. l_knee_flex_percent_stance
#  10. l_knee_flex_at_hs
#  11. l_knee_flex_excursion
#  12. l_knee_add_percent_stance
#  13. l_knee_add_at_hs
#  14. l_knee_abd_percent_stance
#  15. l_knee_abd_at_hs
#  16. l_knee_rot_percent_stance
#  17. l_knee_rot_at_hs
#  18. l_hip_ext_percent_stance
#  19. l_hip_ext_at_hs
#  20. l_hip_ext_excursion
#  21. l_hip_add_percent_stance
#  22. l_hip_add_at_hs
#  23. l_hip_rot_percent_stance
#  24. l_hip_rot_at_hs
#  25. l_foot_ang_at_to
#  26. l_med_heel_whip_peak
#  27. l_mhw_percent_swing
#  28. l_ankle_df_peak_vel
#  29. l_ankle_df_vel_percent_stance
#  30. l_ankle_eve_vel_percent_stance
#  31. l_ankle_rot_vel_percent_stance
#  32. l_knee_flex_peak_vel
#  33. l_knee_flex_vel_percent_stance
#  34. l_knee_abd_vel_percent_stance
#  35. l_knee_add_vel_percent_stance
#  36. l_hip_abd_vel_percent_stance
#  37. r_pelvis_drop_percent_stance
#  38. r_pelvis_drop_at_hs
#  39. r_ankle_df_percent_stance
#  40. r_ankle_df_at_hs
#  41. r_ankle_df_excursion
#  42. r_ankle_eve_at_hs
#  43. r_ankle_rot_percent_stance
#  44. r_ankle_rot_at_hs
#  45. r_knee_flex_percent_stance
#  46. r_knee_flex_at_hs
#  47. r_knee_flex_excursion
#  48. r_knee_add_percent_stance
#  49. r_knee_add_at_hs
#  50. r_knee_abd_percent_stance
#  51. r_knee_abd_at_hs
#  52. r_knee_rot_percent_stance
#  53. r_knee_rot_at_hs
#  54. r_hip_ext_percent_stance
#  55. r_hip_ext_at_hs
#  56. r_hip_ext_excursion
#  57. r_hip_add_percent_stance
#  58. r_hip_add_at_hs
#  59. r_hip_rot_percent_stance
#  60. r_hip_rot_at_hs
#  61. r_foot_ang_at_to
#  62. r_med_heel_whip_peak
#  63. r_mhw_percent_swing
#  64. r_ankle_df_peak_vel
#  65. r_ankle_df_vel_percent_stance
#  66. r_ankle_eve_vel_percent_stance
#  67. r_ankle_rot_vel_percent_stance
#  68. r_knee_flex_peak_vel
#  69. r_knee_flex_vel_percent_stance
#  70. r_knee_abd_vel_percent_stance
#  71. r_knee_add_vel_percent_stance
#  72. r_hip_abd_vel_percent_stance

# %%
columns = ['has_no_injury', 
    'injury_severity_value','InjDefn',
    'injury_code','SpecInjury',
    'injury2_code', 'SpecInjury2',
    'injured_joint_code','InjJoint', 
    'injured_joint2_code', 'InjJoint2'
]
# display(cleaned_session_data_full_part1[columns][cleaned_session_data_full_part1.injury_severity_value == 0].head(10))
display(cleaned_session_data_full_part1[["InjDefn", "InjJoint", "SpecInjury", "SpecInjury2"]][
    (cleaned_session_data_full_part1.injury_code == "no_injury") & (cleaned_session_data_full_part1.injury_severity_value > 0)
].value_counts(dropna=False).sort_index(ascending=False))
# Out:
# InjDefn                             InjJoint   SpecInjury               SpecInjury2
# training volume/intensity affected  other      NaN                      NaN            4
#                                                fill in specifics below  NaN            4
#                                     no injury  NaN                      NaN            1
# continuing to train in pain         other      NaN                      NaN            2
#                                                fill in specifics below  NaN            3
#                                     no injury  NaN                      NaN            1
# 2 workouts missed in a row          other      NaN                      NaN            1
#                                     no injury  NaN                      NaN            1
# Name: count, dtype: int64

# %%
def classify_injury_status(df: pd.DataFrame):
    """
    Classify all subjects in a DataFrame as injured or uninjured.
    
    Args:
        df: DataFrame
            DataFrame containing at least the following columns:
            - injury_code (cleaned version of SpecInjury)
    
    Returns:
        Series: True for UNINJURED, False for INJURED
    """
    # # Check InjDefn condition
    # inj_defn_ok = df['injury_severity_value'] == 0
    
    # # Check InjJoint condition
    # inj_joint_ok = (
    #     (df['injured_joint_code'] == 'no_injury') |
    #     df['InjJoint'].isna() |
    #     df['InjJoint'].isnull()
    # )

    # inj_joint2_ok = (
    #     (df['injured_joint2_code'] == 'no_injury') |
    #     df['InjJoint2'].isna() |
    #     df['InjJoint2'].isnull()

    # )
    
    # Check SpecInjury condition
    spec_injury_ok = (
        (df['injury_code'] == 'no_injury') |
        df['injury_code'].isna() |
        df['injury_code'].isnull()
    )

    # # Check SpecInjury2 condition
    # spec_injury2_ok = (
    #     (df['injury2_code'] == 'no_injury') |
    #     df['injury2_code'].isna() |
    #     df['injury2_code'].isnull()
    # )
    
    return spec_injury_ok

cleaned_session_data_full_part1["has_no_injury"] = classify_injury_status(cleaned_session_data_full_part1)
cleaned_session_data_full_part1["is_injured"] =  ~cleaned_session_data_full_part1["has_no_injury"]

# %%
print(f"Number of healthy sessions: {len(cleaned_session_data_full_part1[cleaned_session_data_full_part1.has_no_injury])}")
df = cleaned_session_data_full_part1[
    ['has_no_injury', 
    'injury_severity_value','InjDefn',
    'injury_code','SpecInjury',
    'injury2_code', 'SpecInjury2',
    'injured_joint_code','InjJoint', 
    'injured_joint2_code', 'InjJoint2'
    ]].value_counts(dropna=False).sort_index(ascending=False)
with pd.option_context('display.max_rows', None):
    display(df)

save_df_as_table_image(
    df[df.index.get_level_values('has_no_injury') == True].reset_index(),
    os.path.join(RICKD_RESULTS_FOLDER, 'no_injury_session_counts.png')
)
# Out:
# Number of healthy sessions: 665
# has_no_injury  injury_severity_value  InjDefn                             injury_code                SpecInjury                                injury2_code         SpecInjury2                    injured_joint_code  InjJoint             injured_joint2_code  InjJoint2
# True           NaN                    NaN                                 no_injury                  no injury                                 no_injury            NaN                            no_injury           NaN                  no_injury            NaN                  70
#                3.0                    2 workouts missed in a row          no_injury                  NaN                                       no_injury            NaN                            other               other                no_injury            NaN                   1
#                                                                                                                                                                                                    no_injury           no injury            no_injury            no injury             1
#                2.0                    training volume/intensity affected  no_injury                  NaN                                       no_injury            NaN                            other               other                other                other                 1
#                                                                                                                                                                                                                                             no_injury            NaN                   3
#                                                                                                                                                                                                    no_injury           no injury            no_injury            no injury             1
#                                                                                                      fill in specifics below                   no_injury            NaN                            other               other                no_injury            no injury             4
#                1.0                    continuing to train in pain         no_injury                  NaN                                       no_injury            NaN                            other               other                no_injury            NaN                   2
#                                                                                                                                                                                                    no_injury           no injury            no_injury            no injury             1
#                                                                                                      fill in specifics below                   no_injury            NaN                            other               other                no_injury            no injury             3
#                0.0                    no injury                           no_injury                  NaN                                       no_injury            NaN                            other               other                no_injury            NaN                   3
#                                                                                                                                                                                                    no_injury           NaN                  no_injury            NaN                 160
#                                                                                                                                                                                                                                                                  no injury             1
#                                                                                                                                                                                                                        no injury,no injury  no_injury            NaN                 189
#                                                                                                                                                                                                                        no injury            no_injury            NaN                  29
#                                                                                                                                                                                                                                                                  no injury           196
# False          NaN                    NaN                                 pate_pain_synd             pfps                                      no_injury            NaN                            knee                knee                 no_injury            NaN                   6
#                                                                           pain                       non-specific injury                       no_injury            NaN                            no_injury           NaN                  no_injury            NaN                   1
#                                                                           motor_vehi_acci            mva, not running related                  no_injury            NaN                            no_injury           NaN                  no_injury            NaN                   1
#                                                                           high_ankle_spra_with_tend  high ankle sprain with tendonosis         no_injury            NaN                            ankle               ankle                no_injury            NaN                   1
#                                                                           gast_stra                  gastrocnemius strain                      no_injury            NaN                            other               other                no_injury            NaN                   1
#                3.0                    2 workouts missed in a row          tibia_stre_frac            tibia stress fracture                     no_injury            NaN                            lower_leg           lower leg            no_injury            NaN                   1
#                                                                           tibia_frac                 tibia fracture                            no_injury            NaN                            lower_leg           lower leg            no_injury            NaN                   1
#                                                                           tend                       tendonitis                                no_injury            NaN                            thigh               thigh                no_injury            NaN                   1
#                                                                                                                                                                                                    knee                knee                 no_injury            no injury             1
#                                                                           stre_frac                  stress fracture                           no_injury            NaN                            hip_pelvis          hip/pelvis           no_injury            NaN                   2
#                                                                           si_joint_pain              si joint pain                             no_injury            NaN                            sacro_joint         sacroiliac joint     no_injury            no injury             1
#                                                                           shin_spli                  shin splints                              no_injury            NaN                            lower_leg           lower leg            no_injury            NaN                
#                                                                                                                                                                                                    lower_leg           lower leg            no_injury            no injury             1
#                                                                           burs                       bursitis                                  no_injury            NaN                            knee                knee                 no_injury            no injury             1
#                                                                           achi_tend                  achilles tendonitis                       no_injury            NaN                            ankle               ankle                no_injury            no injury             1
# Name: count, dtype: int64

# %%
df = cleaned_session_data_full_part1[
    ['has_no_injury', 
    'injury_severity_value','InjDefn',
    'injury_code','SpecInjury',
    'injury2_code', 'SpecInjury2',
    'injured_joint_code','InjJoint', 
    'injured_joint2_code', 'InjJoint2'
    ]][
        (cleaned_session_data_full_part1.has_no_injury == True) & 
        (
            (cleaned_session_data_full_part1.injured_joint_code != "no_injury") |
            (cleaned_session_data_full_part1.injured_joint2_code != "no_injury") |
            (cleaned_session_data_full_part1.injury_severity_value > 0)
        )
    ].value_counts(dropna=False).sort_index(ascending=False)

with pd.option_context('display.max_rows', None):
    display(df)

save_df_as_table_image(
    df.sort_values().head(20).reset_index(),
    os.path.join(RICKD_RESULTS_FOLDER, 'potentially_wrongly_mapped_uninjured_data.png')
)
# Out:
# has_no_injury  injury_severity_value  InjDefn                             injury_code  SpecInjury               injury2_code  SpecInjury2  injured_joint_code  InjJoint   injured_joint2_code  InjJoint2
# True           3.0                    2 workouts missed in a row          no_injury    NaN                      no_injury     NaN          other               other      no_injury            NaN          1
#                                                                                                                                            no_injury           no injury  no_injury            no injury    1
#                2.0                    training volume/intensity affected  no_injury    NaN                      no_injury     NaN          other               other      other                other        1
#                                                                                                                                                                           no_injury            NaN          3
#                                                                                                                                            no_injury           no injury  no_injury            no injury    1
#                                                                                        fill in specifics below  no_injury     NaN          other               other      no_injury            no injury    4
#                1.0                    continuing to train in pain         no_injury    NaN                      no_injury     NaN          other               other      no_injury            NaN          2
#                                                                                                                                            no_injury           no injury  no_injury            no injury    1
#                                                                                        fill in specifics below  no_injury     NaN          other               other      no_injury            no injury    3
#                0.0                    no injury                           no_injury    NaN                      no_injury     NaN          other               other      no_injury            NaN          3
# Name: count, dtype: int64

# %%
# Age of 255 is clearly an outlier, replace with Nan.
cleaned_session_data_full_part2 = cleaned_session_data_full_part1.copy()
plt.figure(figsize=(8, 4))
plt.boxplot(cleaned_session_data_full_part2['age'].dropna(), vert=False)
plt.title('Boxplot of Age')
plt.xlabel('Age')
plt.show()

# Replace outliers in 'age' with NaN
outlier_mask = cleaned_session_data_full_part2['age'] > 100
cleaned_session_data_full_part2.loc[outlier_mask, 'age'] = np.nan
print(f"NewMax Age: {cleaned_session_data_full_part2['age'].max()}, Min Age: {cleaned_session_data_full_part2['age'].min()}")
# Out:
# NewMax Age: 73.0, Min Age: 18.0

# %%
# Height of 999 is clearly an outlier, replace with Nan.

plt.figure(figsize=(8, 4))
plt.boxplot(cleaned_session_data_full_part2['Height'].dropna(), vert=False)
plt.title('Boxplot of Height')
plt.xlabel('Height')
plt.show()

outlier_mask = (cleaned_session_data_full_part2['Height'] > 300) | (cleaned_session_data_full_part2['Height'] < 50)
cleaned_session_data_full_part2.loc[outlier_mask, 'Height'] = np.nan
print(f"New Max Height: {cleaned_session_data_full_part2['Height'].max()}, Min Height: {cleaned_session_data_full_part2['Height'].min()}")
# Out:
# New Max Height: 196.5, Min Height: 120.0

# %%
# Weight of 1564 is clearly an outlier, replace with Nan.

plt.figure(figsize=(8, 4))
plt.boxplot(cleaned_session_data_full_part2['Weight'].dropna(), vert=False)
plt.title('Boxplot of Weight')
plt.xlabel('Weight')
plt.show()

outlier_mask = (cleaned_session_data_full_part2['Weight'] < 25) | (cleaned_session_data_full_part2['Weight'] > 300)
cleaned_session_data_full_part2.loc[outlier_mask, 'Weight'] = np.nan
print(f"New Max Weight: {cleaned_session_data_full_part2['Weight'].max()}, Min Weight: {cleaned_session_data_full_part2['Weight'].min()}")
# Out:
# New Max Weight: 176.0, Min Weight: 42.5

# %%
# InjDuration of 3000 is suspicious

plt.figure(figsize=(8, 4))
plt.boxplot(cleaned_session_data_full_part2['InjDuration'].dropna(), vert=False)
plt.title('Boxplot of InjDuration')
plt.xlabel('InjDuration')
plt.show()

# For cronic injuries the duration could be the age of the subject.
outlier_mask = cleaned_session_data_full_part2['InjDuration'] > (cleaned_session_data_full_part2['age'] * 365)
display(cleaned_session_data_full_part2[outlier_mask][['id', 'age','injury_code', 'InjDuration']])
cleaned_session_data_full_part2.loc[outlier_mask, 'InjDuration'] = np.nan
print(f"New Max InjDuration: {cleaned_session_data_full_part2['Weight'].max()}, Min InjDuration: {cleaned_session_data_full_part2['Weight'].min()}")
# Out:
#                           id   age injury_code  InjDuration
# 1741  200371_20141020t135011  33.0   shin_spli      30000.0
# New Max InjDuration: 176.0, Min InjDuration: 42.5

# %%
# YearsRunning of 999 is clearly an outlier, replace with Nan.

plt.figure(figsize=(8, 4))
plt.boxplot(cleaned_session_data_full_part2['YrsRunning'].dropna(), vert=False)
plt.title('Boxplot of YrsRunning')
plt.xlabel('YrsRunning')
plt.show()

# For cronic injuries the duration could be the age of the subject.
outlier_mask = cleaned_session_data_full_part2['YrsRunning'] > (cleaned_session_data_full_part2['age'])
display(cleaned_session_data_full_part2[outlier_mask][['id', 'age', 'YrsRunning']].head(5))
cleaned_session_data_full_part2.loc[outlier_mask, 'YrsRunning'] = np.nan
print(f"New Max YrsRunning: {cleaned_session_data_full_part2['YrsRunning'].max()}, Min YrsRunning: {cleaned_session_data_full_part2['Weight'].min()}")
# Out:
#                           id   age  YrsRunning
# 643   100168_20100824t164805  50.0       999.0
# 656   100181_20101026t163032  43.0       999.0
# 1141  100232_20090527t000000  22.0       999.0
# 1142  100242_20090617t131821  54.0       999.0
# 1145  100244_20090709t124813  23.0       999.0
# New Max YrsRunning: 54.0, Min YrsRunning: 42.5

# %%
cleaned_session_data_full_part2[['Level']].value_counts(dropna=False)
# Out:
# Level
# recreational    1042
# competitive      521
# NaN              269
# Name: count, dtype: int64

# %%
outlier_mask = (cleaned_session_data_full_part2['Gender'] != 'male') & (cleaned_session_data_full_part2['Gender'] != 'female')
cleaned_session_data_full_part2.loc[outlier_mask, 'Gender'] = np.nan
cleaned_session_data_full_part2["Gender"].value_counts(dropna=False)
# Out:
# Gender
# female    926
# male      905
# NaN         1
# Name: count, dtype: int64

# %%
for col in cleaned_session_data_full_part2.columns:
    print(f"'{col}',")
# Out:
# 'id',
# 'sub_id',
# 'datestring',
# 'filename',
# 'speed_r',
# 'age',
# 'Height',
# 'Weight',
# 'Gender',
# 'DominantLeg',
# 'InjDefn',
# 'InjJoint',
# 'InjSide',
# 'SpecInjury',
# 'InjDuration',
# 'InjJoint2',
# 'InjSide2',
# 'SpecInjury2',
# 'Activities',
# 'Level',
# 'YrsRunning',
# 'RaceDistance',
# 'RaceTimeHrs',
# 'RaceTimeMins',
# 'RaceTimeSecs',
# 'YrPR',
# 'NumRaces',
# 'sub_id_orig',
# 'session_file_path',
# 'l_step_width',
# 'l_stride_rate',
# 'l_stride_length',
# 'l_swing_time',
# 'l_stance_time',
# 'l_pelvis_peak_drop_angle',
# 'l_pelvis_drop_excursion',
# 'l_ankle_df_peak_angle',
# 'l_ankle_eve_peak_angle',
# 'l_ankle_eve_percent_stance',
# 'l_ankle_eve_excursion',
# 'l_ankle_rot_peak_angle',
# 'l_ankle_rot_excursion',
# 'l_knee_flex_peak_angle',
# 'l_knee_add_peak_angle',
# 'l_knee_add_excursion',
# 'l_knee_abd_peak_angle',
# 'l_knee_abd_excursion',
# 'l_knee_rot_peak_angle',
# 'l_knee_rot_excursion',
# 'l_hip_ext_peak_angle',
# 'l_hip_add_peak_angle',
# 'l_hip_add_excursion',
# 'l_hip_rot_peak_angle',
# 'l_hip_rot_excursion',
# 'l_foot_prog_angle',
# 'l_foot_ang_at_hs',
# 'l_mhw_exc_from_to',
# 'l_ankle_eve_peak_vel',
# 'l_ankle_rot_peak_vel',
# 'l_knee_abd_peak_vel',
# 'l_knee_add_peak_vel',
# 'l_hip_abd_peak_vel',
# 'l_knee_rot_peak_vel',
# 'l_hip_rot_peak_vel',
# 'l_pronation_onset',
# 'l_pronation_offset',
# 'l_peak_hip_add_velocity',
# 'l_peak_pelvic_drop_velocity',
# 'l_vertical_oscillation',
# 'r_step_width',
# 'r_stride_rate',
# 'r_stride_length',
# 'r_swing_time',
# 'r_stance_time',
# 'r_pelvis_peak_drop_angle',
# 'r_pelvis_drop_excursion',
# 'r_ankle_df_peak_angle',
# 'r_ankle_eve_peak_angle',
# 'r_ankle_eve_percent_stance',
# 'r_ankle_eve_excursion',
# 'r_ankle_rot_peak_angle',
# 'r_ankle_rot_excursion',
# 'r_knee_flex_peak_angle',
# 'r_knee_add_peak_angle',
# 'r_knee_add_excursion',
# 'r_knee_abd_peak_angle',
# 'r_knee_abd_excursion',
# 'r_knee_rot_peak_angle',
# 'r_knee_rot_excursion',
# 'r_hip_ext_peak_angle',
# 'r_hip_add_peak_angle',
# 'r_hip_add_excursion',
# 'r_hip_rot_peak_angle',
# 'r_hip_rot_excursion',
# 'r_foot_prog_angle',
# 'r_foot_ang_at_hs',
# 'r_mhw_exc_from_to',
# 'r_ankle_eve_peak_vel',
# 'r_ankle_rot_peak_vel',
# 'r_knee_abd_peak_vel',
# 'r_knee_add_peak_vel',
# 'r_hip_abd_peak_vel',
# 'r_knee_rot_peak_vel',
# 'r_hip_rot_peak_vel',
# 'r_pronation_onset',
# 'r_pronation_offset',
# 'r_peak_hip_add_velocity',
# 'r_peak_pelvic_drop_velocity',
# 'r_vertical_oscillation',
# 'injury_severity_code',
# 'injury_severity_value',
# 'injury_code',
# 'injury2_code',
# 'injury_desc',
# 'injury2_desc',
# 'injury_name',
# 'injury2_name',
# 'injured_joint_code',
# 'injured_joint2_code',
# 'injured_side_code',
# 'injured_side2_code',
# 'has_no_injury',
# 'is_injured',

# %%
cleaned_session_data_full_part2["id"] = cleaned_session_data_full_part2["id"].str.upper()

# %%
from core.constants import RICKD_SESSION_DATA_FULL_CLEANED_FILE
# Keep only the relevant columns
cols_to_drop = [
    'InjDefn',
    'InjJoint',
    'InjSide',
    'SpecInjury',
    'InjDuration',
    'InjJoint2',
    'InjSide2',
    'SpecInjury2',
    'sub_id_orig',
]
cleaned_session_data_full = cleaned_session_data_full_part2.drop(columns=cols_to_drop)
cleaned_session_data_full.to_csv(RICKD_SESSION_DATA_FULL_CLEANED_FILE, index=False)
cleaned_session_data_full.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1832 entries, 0 to 1831
# Data columns (total 114 columns):
#  #    Column                       Dtype
# ---   ------                       -----
#  0    id                           object
#  1    sub_id                       int64
#  2    datestring                   datetime64[ns]
#  3    filename                     object
#  4    speed_r                      float64
#  5    age                          float64
#  6    Height                       float64
#  7    Weight                       float64
#  8    Gender                       object
#  9    DominantLeg                  object
#  10   Activities                   object
#  11   Level                        object
#  12   YrsRunning                   float64
#  13   RaceDistance                 object
#  14   RaceTimeHrs                  float64
#  15   RaceTimeMins                 float64
#  16   RaceTimeSecs                 float64
#  17   YrPR                         float64
#  18   NumRaces                     float64
#  19   session_file_path            object
#  20   l_step_width                 float64
#  21   l_stride_rate                float64
#  22   l_stride_length              float64
#  23   l_swing_time                 float64
#  24   l_stance_time                float64
#  25   l_pelvis_peak_drop_angle     float64
#  26   l_pelvis_drop_excursion      float64
#  27   l_ankle_df_peak_angle        float64
#  28   l_ankle_eve_peak_angle       float64
#  29   l_ankle_eve_percent_stance   float64
#  30   l_ankle_eve_excursion        float64
#  31   l_ankle_rot_peak_angle       float64
#  32   l_ankle_rot_excursion        float64
#  33   l_knee_flex_peak_angle       float64
#  34   l_knee_add_peak_angle        float64
#  35   l_knee_add_excursion         float64
#  36   l_knee_abd_peak_angle        float64
#  37   l_knee_abd_excursion         float64
#  38   l_knee_rot_peak_angle        float64
#  39   l_knee_rot_excursion         float64
#  40   l_hip_ext_peak_angle         float64
#  41   l_hip_add_peak_angle         float64
#  42   l_hip_add_excursion          float64
#  43   l_hip_rot_peak_angle         float64
#  44   l_hip_rot_excursion          float64
#  45   l_foot_prog_angle            float64
#  46   l_foot_ang_at_hs             float64
#  47   l_mhw_exc_from_to            float64
#  48   l_ankle_eve_peak_vel         float64
#  49   l_ankle_rot_peak_vel         float64
#  50   l_knee_abd_peak_vel          float64
#  51   l_knee_add_peak_vel          float64
#  52   l_hip_abd_peak_vel           float64
#  53   l_knee_rot_peak_vel          float64
#  54   l_hip_rot_peak_vel           float64
#  55   l_pronation_onset            int64
#  56   l_pronation_offset           int64
#  57   l_peak_hip_add_velocity      float64
#  58   l_peak_pelvic_drop_velocity  float64
#  59   l_vertical_oscillation       float64
#  60   r_step_width                 float64
#  61   r_stride_rate                float64
#  62   r_stride_length              float64
#  63   r_swing_time                 float64
#  64   r_stance_time                float64
#  65   r_pelvis_peak_drop_angle     float64
#  66   r_pelvis_drop_excursion      float64
#  67   r_ankle_df_peak_angle        float64
#  68   r_ankle_eve_peak_angle       float64
#  69   r_ankle_eve_percent_stance   float64
#  70   r_ankle_eve_excursion        float64
#  71   r_ankle_rot_peak_angle       float64
#  72   r_ankle_rot_excursion        float64
#  73   r_knee_flex_peak_angle       float64
#  74   r_knee_add_peak_angle        float64
#  75   r_knee_add_excursion         float64
#  76   r_knee_abd_peak_angle        float64
#  77   r_knee_abd_excursion         float64
#  78   r_knee_rot_peak_angle        float64
#  79   r_knee_rot_excursion         float64
#  80   r_hip_ext_peak_angle         float64
#  81   r_hip_add_peak_angle         float64
#  82   r_hip_add_excursion          float64
#  83   r_hip_rot_peak_angle         float64
#  84   r_hip_rot_excursion          float64
#  85   r_foot_prog_angle            float64
#  86   r_foot_ang_at_hs             float64
#  87   r_mhw_exc_from_to            float64
#  88   r_ankle_eve_peak_vel         float64
#  89   r_ankle_rot_peak_vel         float64
#  90   r_knee_abd_peak_vel          float64
#  91   r_knee_add_peak_vel          float64
#  92   r_hip_abd_peak_vel           float64
#  93   r_knee_rot_peak_vel          float64
#  94   r_hip_rot_peak_vel           float64
#  95   r_pronation_onset            int64
#  96   r_pronation_offset           int64
#  97   r_peak_hip_add_velocity      float64
#  98   r_peak_pelvic_drop_velocity  float64
#  99   r_vertical_oscillation       float64
#  100  injury_severity_code         object
#  101  injury_severity_value        float64
#  102  injury_code                  object
#  103  injury2_code                 object
#  104  injury_desc                  object
#  105  injury2_desc                 object
#  106  injury_name                  object
#  107  injury2_name                 object
#  108  injured_joint_code           object
#  109  injured_joint2_code          object
#  110  injured_side_code            object
#  111  injured_side2_code           object
#  112  has_no_injury                bool
#  113  is_injured                   bool
# dtypes: bool(2), datetime64[ns](1), float64(87), int64(5), object(19)
# memory usage: 1.6+ MB

# %%
# Identify empty or NaN values in the cleaned_session_data_full DataFrame

import pandas as pd

# Count of NaN values per column
nan_counts = cleaned_session_data_full.isna().sum()
print("NaN counts per column:")
print(nan_counts[nan_counts > 0])

# Percentage of NaN values per column
nan_percent = cleaned_session_data_full.isna().mean() * 100
print("\nPercentage of NaN values per column:")
print(nan_percent[nan_percent > 0].sort_values(ascending=False))

# Optionally, show rows with any NaN values
print("\nRows with any NaN values (showing first 5):")
display(cleaned_session_data_full[cleaned_session_data_full.isna().any(axis=1)].head())
# Out:
# NaN counts per column:
# datestring                  10
# age                          1
# Height                       8
# Weight                       5
# Gender                       1
# DominantLeg                352
# Activities                 316
# Level                      269
# YrsRunning                 568
# RaceDistance               338
# RaceTimeHrs               1277
# RaceTimeMins              1131
# RaceTimeSecs              1387
# YrPR                      1407
# NumRaces                  1328
# l_vertical_oscillation      13
# r_vertical_oscillation      13
# injury_severity_code        80
# injury_severity_value       80
# dtype: int64
#
# Percentage of NaN values per column:
# YrPR                      76.801310
# RaceTimeSecs              75.709607
# NumRaces                  72.489083
# RaceTimeHrs               69.705240
# RaceTimeMins              61.735808
# YrsRunning                31.004367
# DominantLeg               19.213974
# RaceDistance              18.449782
# Activities                17.248908
# Level                     14.683406
# injury_severity_code       4.366812
# injury_severity_value      4.366812
# l_vertical_oscillation     0.709607
# r_vertical_oscillation     0.709607
# datestring                 0.545852
# Height                     0.436681
# Weight                     0.272926
# age                        0.054585
# Gender                     0.054585
# dtype: float64
#
# Rows with any NaN values (showing first 5):
#                        id  sub_id          datestring              filename  \
# 0  100433_20101005T132240  100433 2010-10-05 13:22:40  20101005t132240.json
# 1  100434_20101117T132240  100434 2010-11-17 13:22:40  20101117t132240.json
# 2  100537_20120703T102550  100537 2012-07-03 10:25:50  20120703t102550.json
# 3  100560_20120717T103748  100560 2012-07-17 10:37:48  20120717t103748.json
# 4  101481_20120717T105021  101481 2012-07-17 10:50:21  20120717t105021.json
#
#     speed_r   age  Height  Weight  Gender DominantLeg  ...  \
# 0  1.610861  53.0     NaN     NaN     NaN         NaN  ...
# 1  2.237294  51.0     NaN     NaN  female         NaN  ...
# 2  2.127441   NaN   173.1    67.6  female       right  ...
# 3  2.657365  33.0   179.3    83.0  female       right  ...
# 4  2.625088  32.0   176.3    58.6  female         NaN  ...
#
#                                          injury_desc  \
# 0  General sensation of discomfort  without speci...
# 1  Breakdown and gradual loss of spinal disc cush...
# 2  General sensation of discomfort  without speci...
# 3                      No injury has been diagnosed.
# 4                      No injury has been diagnosed.
#
#                     injury2_desc        injury_name injury2_name  \
# 0  No injury has been diagnosed.               pain    no injury
# 1  No injury has been diagnosed.  disc degeneration    no injury
# 2  No injury has been diagnosed.               pain    no injury
# 3  No injury has been diagnosed.          no injury    no injury
# 4  No injury has been diagnosed.          no injury    no injury
#
#    injured_joint_code  injured_joint2_code  injured_side_code  \
# 0                knee            no_injury              right
# 1        lumbar_spine            no_injury          bilateral
# 2          hip_pelvis            no_injury              right
# 3           no_injury            no_injury              right
# 4           no_injury            no_injury          no_injury
#
#    injured_side2_code  has_no_injury is_injured
# 0               right          False       True
# 1               right          False       True
# 2               right          False       True
# 3               right           True      False
# 4           no_injury           True      False
#
# [5 rows x 114 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
cleaned_session_data_full['Num'].dropna().hist(bins=30)
plt.xlabel('YrPR')
plt.ylabel('Count')
plt.title('Distribution of YrPR')
plt.tight_layout()
plt.show()
